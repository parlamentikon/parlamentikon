# %% [markdown]
# # Stenozaznamy

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../..'))

# %%
from datetime import datetime

# %%
from parlamentikon.Snemovna import *
from parlamentikon.Stenozaznamy import *
from parlamentikon.utility import *

# %% [markdown]
# ## Tabulka Steno

# %%
s = Steno()
s.head()
# Out:
# 2021-03-19:13:59:34 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-19:13:59:35 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  id_organ  schuze  turn                  od_steno  jd  od_t  \
# 49626    115470       172       1     1 2017-11-20 00:00:00+01:00   1   780
# 49627    115471       172       1     2 2017-11-20 00:00:00+01:00   1   790
# 49628    115472       172       1     3 2017-11-20 00:00:00+01:00   1   800
# 49629    115473       172       1     4 2017-11-20 00:00:00+01:00   1   810
# 49630    115474       172       1     5 2017-11-20 00:00:00+01:00   1   820
#
#        do_t
# 49626   790
# 49627   800
# 49628   810
# 49629   820
# 49630   830

# %%
s.popis()
# Out:
# Počet řádků v tabulce: 10140
#
# Sloupce s jedinou hodnotou:
#   'id_organ' má všude hodnotu '172'
#
# Nulové hodnoty:
# Tabulka neobsahuje žádné nulové hodnoty [NaNy atp.]
#           počet unikátních hodnot  počet nenulových hodnot  \
# id_steno                    10140                    10140
# id_organ                        1                    10140
# schuze                         90                    10140
# turn                          456                    10140
# od_steno                      268                    10140
# jd                             12                    10140
# od_t                          274                    10140
# do_t                          484                    10140
#
#                                     typ tabulka vlastni  \
# id_steno                          Int64   steno   False
# id_organ                          Int64   steno   False
# schuze                            Int64   steno   False
# turn                              Int64   steno   False
# od_steno  datetime64[ns, Europe/Prague]   steno   False
# jd                                Int64   steno   False
# od_t                              Int64   steno   False
# do_t                              Int64   steno   False
#
#                                                       popis
# id_steno                         Identifikátor stenozáznamu
# id_organ  Identifikátor orgánu stenozáznamu (v případě P...
# schuze                                        Číslo schůze.
# turn      Číslo stenozáznamu (turn). Pokud číselná řada ...
# od_steno                        Datum začátku stenozáznamu.
# jd        Číslo jednacího dne v rámci schůze (používá se...
# od_t      Čas začátku stenozáznamu v minutách od začátku...
# do_t      Čas konce stenozáznamu v minutách od začátku k...

# %% [markdown]
# ## Tabulka StenoBod

# %%
sb = StenoBod()
sb.tail()
# Out:
# 2021-03-19:13:59:38 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-19:13:59:39 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  aname  id_bod  id_organ  schuze  turn  \
# 20957    126107    784   44627       172      87   234
# 20958    126109    789   44628       172      87   237
# 20959    126119    811   44523       172      87   246
# 20960    126140    932   44360       172      87   269
# 20961    126158    959   44363       172      87   287
#
#                        od_steno  jd  od_t  do_t
# 20957 2021-03-11 00:00:00+01:00   7   670   680
# 20958 2021-03-11 00:00:00+01:00   7   700   710
# 20959 2021-03-11 00:00:00+01:00   7   870   880
# 20960 2021-03-12 00:00:00+01:00   8   560   562
# 20961 2021-03-12 00:00:00+01:00   8   790   800

# %%
sb.popis()
# Out:
# Počet řádků v tabulce: 2105
#
# Sloupce s jedinou hodnotou:
#   'id_organ' má všude hodnotu '172'
#
# Nulové hodnoty:
# Tabulka neobsahuje žádné nulové hodnoty [NaNy atp.]
#           počet unikátních hodnot  počet nenulových hodnot  \
# id_steno                     1703                     2105
# aname                        1088                     2105
# id_bod                       1716                     2105
# id_organ                        1                     2105
# schuze                         77                     2105
# turn                          421                     2105
# od_steno                      259                     2105
# jd                             12                     2105
# od_t                          148                     2105
# do_t                          156                     2105
#
#                                     typ    tabulka vlastni  \
# id_steno                          Int64  steno_bod   False
# aname                             Int64  steno_bod   False
# id_bod                            Int64  steno_bod   False
# id_organ                          Int64      steno   False
# schuze                            Int64      steno   False
# turn                              Int64      steno   False
# od_steno  datetime64[ns, Europe/Prague]      steno   False
# jd                                Int64      steno   False
# od_t                              Int64      steno   False
# do_t                              Int64      steno   False
#
#                                                       popis
# id_steno    Identifikátor stenozáznamu, viz steno:id_steno.
# aname                        Pozice v indexu jednacího dne.
# id_bod    Identifikace bodu pořadu schůze, viz bod_schuz...
# id_organ  Identifikátor orgánu stenozáznamu (v případě P...
# schuze                                        Číslo schůze.
# turn      Číslo stenozáznamu (turn). Pokud číselná řada ...
# od_steno                        Datum začátku stenozáznamu.
# jd        Číslo jednacího dne v rámci schůze (používá se...
# od_t      Čas začátku stenozáznamu v minutách od začátku...
# do_t      Čas konce stenozáznamu v minutách od začátku k...

# %% [markdown]
# ## Tabulka StenoRecnici

# %%
sr = StenoRecnici()
sr.tail()
# Out:
# 2021-03-19:13:59:41 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-19:13:59:43 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  id_osoba  aname  id_bod  druh__ORIG          druh  id_organ  \
# 71138    126162      6531      1   44363           4  předsedající       172
# 71139    126162      6531      3   44363           4  předsedající       172
# 71140    126162      6531      5   44363           4  předsedající       172
# 71141    126162      6531      7   44363           4  předsedající       172
# 71142    126162      6531      9   44363           4  předsedající       172
#
#        schuze  turn                  od_steno  ...  do_t  pred  prijmeni  \
# 71138      87   290 2021-03-12 00:00:00+01:00  ...   827   Bc.     Pikal
# 71139      87   290 2021-03-12 00:00:00+01:00  ...   827   Bc.     Pikal
# 71140      87   290 2021-03-12 00:00:00+01:00  ...   827   Bc.     Pikal
# 71141      87   290 2021-03-12 00:00:00+01:00  ...   827   Bc.     Pikal
# 71142      87   290 2021-03-12 00:00:00+01:00  ...   827   Bc.     Pikal
#
#          jmeno za                  narozeni pohlavi__ORIG zmena umrti pohlavi
# 71138  Vojtěch    1987-02-19 00:00:00+01:00             M   NaT   NaT     muž
# 71139  Vojtěch    1987-02-19 00:00:00+01:00             M   NaT   NaT     muž
# 71140  Vojtěch    1987-02-19 00:00:00+01:00             M   NaT   NaT     muž
# 71141  Vojtěch    1987-02-19 00:00:00+01:00             M   NaT   NaT     muž
# 71142  Vojtěch    1987-02-19 00:00:00+01:00             M   NaT   NaT     muž
#
# [5 rows x 22 columns]

# %%
sr.popis()
# Out:
# Počet řádků v tabulce: 71143
#
# Sloupce s jedinou hodnotou:
#   'id_organ' má všude hodnotu '172'
#
# Nulové hodnoty:
# Sloupec 'id_bod' obsahuje 14.41% (10250 z 71143) nulových hodnot (např. NaNů).
# Sloupec 'narozeni' obsahuje 0.24% (171 z 71143) nulových hodnot (např. NaNů).
# Sloupec 'zmena' obsahuje 86.91% (61827 z 71143) nulových hodnot (např. NaNů).
# Sloupec 'umrti' obsahuje 100.00% (71143 z 71143) nulových hodnot (např. NaNů).
#                počet unikátních hodnot  počet nenulových hodnot  \
# id_steno                          9361                    71143
# id_osoba                           293                    71143
# aname                               40                    71143
# id_bod                            1697                    60893
# druh__ORIG                           5                    71143
# druh                                 5                    71143
# id_organ                             1                    71143
# schuze                              90                    71143
# turn                               456                    71143
# od_steno                           268                    71143
# jd                                  12                    71143
# od_t                               271                    71143
# do_t                               478                    71143
# pred                                36                    71143
# prijmeni                           285                    71143
# jmeno                              108                    71143
# za                                  19                    71143
# narozeni                           253                    70972
# pohlavi__ORIG                        3                    71143
# zmena                                5                     9316
# umrti                                0                        0
# pohlavi                              2                    71143
#
#                                          typ        tabulka vlastni  \
# id_steno                               Int64  steno_recnici   False
# id_osoba                               Int64  steno_recnici   False
# aname                                  Int64  steno_recnici   False
# id_bod                                 Int64  steno_recnici   False
# druh__ORIG                             Int64  steno_recnici   False
# druh                                  string  steno_recnici    True
# id_organ                               Int64          steno   False
# schuze                                 Int64          steno   False
# turn                                   Int64          steno   False
# od_steno       datetime64[ns, Europe/Prague]          steno   False
# jd                                     Int64          steno   False
# od_t                                   Int64          steno   False
# do_t                                   Int64          steno   False
# pred                                  string          osoby   False
# prijmeni                              string          osoby   False
# jmeno                                 string          osoby   False
# za                                    string          osoby   False
# narozeni       datetime64[ns, Europe/Prague]          osoby   False
# pohlavi__ORIG                         string          osoby   False
# zmena          datetime64[ns, Europe/Prague]          osoby   False
# umrti          datetime64[ns, Europe/Prague]          osoby   False
# pohlavi                               string          osoby    True
#
#                                                            popis
# id_steno         Identifikátor stenozáznamu, viz Steno:id_steno.
# id_osoba                Identifikátor osoby, viz Osoby:id_osoba.
# aname              Identifikace vystoupení v rámci stenozáznamu.
# id_bod         Identifikace bodu pořadu schůze, viz bod_schuz...
# druh__ORIG     Druh vystoupení řečníka: 0 či null - neznámo, ...
# druh                                    Druh vystoupení řečníka.
# id_organ       Identifikátor orgánu stenozáznamu (v případě P...
# schuze                                             Číslo schůze.
# turn           Číslo stenozáznamu (turn). Pokud číselná řada ...
# od_steno                             Datum začátku stenozáznamu.
# jd             Číslo jednacího dne v rámci schůze (používá se...
# od_t           Čas začátku stenozáznamu v minutách od začátku...
# do_t           Čas konce stenozáznamu v minutách od začátku k...
# pred                                           Titul pred jmenem
# prijmeni       Příjmení, v některých případech obsahuje i dod...
# jmeno                                                      Jméno
# za                                               Titul za jménem
# narozeni            Datum narození, pokud neznámo, pak 1.1.1900.
# pohlavi__ORIG        Pohlaví, "M" jako muž, ostatní hodnoty žena
# zmena                                       Datum posledni změny
# umrti                                                Datum úmrtí
# pohlavi                                                 Pohlaví.

# %%
print(f"Poslední běh notebooku dokončen {datetime.now().strftime('%d.%m.%Y v %H:%M:%S')}.")
# Out:
# Poslední běh notebooku dokončen 19.03.2021 v 13:59:47.
